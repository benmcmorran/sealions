# %%
import glob
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
# %matplotlib notebook

# %%
with open('sliced_small_instances.json') as in_f:
    instances = json.load(in_f)
    images = instances['images']
    annotations = instances['annotations']

# %%
ann = annotations[204]
img_id = ann['image_id']
img = cv2.imread('./data/Sliced/{0}'.format(img_id))
img = cv2.cvtColor(img, cv2.cv.CV_BGR2RGB)
anns = [a for a in annotations if a['image_id'] == img_id]
for sub_ann in anns:
    bb = sub_ann['bbox']
    cv2.rectangle(img,(bb[1],bb[0]),(bb[1]+50,bb[0] + 50),(255,0,0),2)
plt.close()
plt.imshow(img)
cv2.imwrite('test.jpg', img)
# Out:
# <img src="data:image/png;base64,..." width="640">
# True

# %%
# there is a ~200 lost annotatiosn
print len(annotations)
with open('small_instances.json') as in_f:
    big_instances = json.load(in_f)
    big_annotations = big_instances['annotations']
print len(big_annotations)
# Out:
# 801
# 1018

# %%
### were the original accurate?
ann = big_annotations[204]
img_id = ann['image_id']
print img_id
img = cv2.imread('./data/TrainDotted/{0}.jpg'.format(img_id))
img = cv2.cvtColor(img, cv2.cv.CV_BGR2RGB)
anns = [a for a in big_annotations if a['image_id'] == img_id]
for sub_ann in anns:
    bb = sub_ann['bbox']
    cv2.rectangle(img,(bb[1],bb[0]),(bb[1]+50,bb[0] + 50),(255,0,0),2)
plt.close()
fig = plt.gcf()
plt.imshow(img, aspect='auto')
cv2.imwrite('test.jpg', img)
# Out:
# 43
# <img src="data:image/png;base64,..." width="640">
# True
